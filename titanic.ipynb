# %% [markdown]
# 根据之前的知识，我们现在来进行一些训练。<br>
# In this challenge, we ask you to build a predictive model that answers the question: “what sorts of people were more likely to survive?” <br>
# using passenger data (ie name, age, gender, socio-economic class, etc).<br>
# <br>
# Variable Notes<br>
# <br>
# pclass: A proxy for socio-economic status (SES)<br>
# 1st = Upper<br>
# 2nd = Middle<br>
# 3rd = Lower<br>
# <br>
# age: Age is fractional if less than 1. If the age is estimated, is it in the form of xx.5<br>
# <br>
# sibsp: The dataset defines family relations in this way...<br>
# <br>
# Sibling = brother, sister, stepbrother, stepsister<br>
# <br>
# Spouse = husband, wife (mistresses and fiancés were ignored)<br>
# <br>
# parch: The dataset defines family relations in this way...<br>
# <br>
# Parent = mother, father<br>
# <br>
# Child = daughter, son, stepdaughter, stepson<br>
# Some children travelled only with a nanny, therefore parch=0 for them.<br>

# %%
import torch
import pandas as pd
from sklearn.preprocessing import StandardScaler, LabelEncoder
from torch.utils.data import DataLoader,TensorDataset
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

#加载文件
train_df = pd.read_csv('./dataset/titanic/train.csv')
test_df = pd.read_csv('./dataset/titanic/test.csv')

#print(train_df.isnull().sum())
#print(test_df.isnull().sum())

#填补空缺
#inplace=true表示在原数据框内填写，不创建新副本。
train_df['Age'].fillna(train_df['Age'].mean(),inplace = True)
#.mode()是为了找众数，[0]是因为众数可能不止一个，取第一个数
train_df['Embarked'].fillna(train_df['Embarked'].mode()[0],inplace = True)
train_df['Fare'].fillna(train_df['Fare'].median(),inplace= True)
train_df['Cabin'].fillna('Unknown',inplace=True)
train_df['Name'].fillna('Unknown',inplace=True)
train_df['Ticket'].fillna('Unknown',inplace=True)

test_df['Age'].fillna(test_df['Age'].mean(),inplace=True)
test_df['Embarked'].fillna(test_df['Embarked'].mode()[0],inplace= True)
test_df['Fare'].fillna(test_df['Fare'].median(),inplace=True)
test_df['Cabin'].fillna('Unknown',inplace=True)
test_df['Name'].fillna('Unknown',inplace=True)
test_df['Ticket'].fillna('Unknown',inplace=True)

#Sex encode
#讲分类变量转化为数值
#.fit_transform先拟合数据，然后进行转换
#.transform将拟合好的编码器用于新的数据
labelencoder_sex = LabelEncoder()
train_df['Sex'] = labelencoder_sex.fit_transform(train_df['Sex'])
test_df['Sex'] = labelencoder_sex.transform(test_df['Sex'])

#Embarked one-hot encode
#pd.getdimmies将分类变量转化为onehot编码，columns指定需要编码的列
#drop_first=Ture删除第一个类别避免多重共线性
train_df = pd.get_dummies(train_df,columns=['Embarked'],drop_first=True)
test_df = pd.get_dummies(test_df,columns=['Embarked'],drop_first=True)


#title encode
train_df['Title'] = train_df['Name'].apply(lambda x: x.split(',')[1].split('.')[0].strip())
test_df['Title'] = test_df['Name'].apply(lambda x: x.split(',')[1].split('.')[0].strip())


for df in [train_df,test_df]:
    df['Title'] = df['Title'].replace(['Mlle','Ms'],'Miss')
    df['Title'] = df['Title'].replace(['Mme'],'Mrs')
    df['Title'] = df['Title'].replace(['Dr','Rev','Col','Major','jonkheer','Capt','Don','Sir','Lady','Countess','Dona'],'Rare')

labelencoder_title = LabelEncoder()
train_df['Title'] = labelencoder_title.fit_transform(train_df['Title'])
test_df['Title'] = labelencoder_title.transform(test_df['Title'])

#Carbin encode

train_df['Cabin'] = train_df['Cabin'].apply(lambda x: x[0])
test_df['Cabin'] = test_df['Cabin'].apply(lambda x : x[0])
labelencoder_carbin = LabelEncoder()
train_df['Cabin'] = labelencoder_carbin.fit_transform(train_df['Cabin'])
test_df['Cabin'] = labelencoder_carbin.transform(test_df['Cabin'])

#ticket encode

def process_ticket(ticket):
    #去掉ticket两边的空格，然后按照‘ ’（空格）区分，然后取最后一列。
    ticket = ticket.strip().split(' ')[-1]
    return 'X' if not ticket.isdigit() else ticket

train_df['Ticket'] = train_df['Ticket'].apply(process_ticket)
test_df['Ticket'] = test_df['Ticket'].apply(process_ticket)
combined_tickets = pd.concat([train_df['Ticket'], test_df['Ticket']], axis=0)
labelencoder_ticket = LabelEncoder()
labelencoder_ticket.fit(combined_tickets)
train_df['Ticket'] = labelencoder_ticket.transform(train_df['Ticket'])
test_df['Ticket'] = labelencoder_ticket.transform(test_df['Ticket'])

#choose feature and in-outputs
features = ['Pclass','Title','Sex','Age','SibSp','Parch','Ticket','Fare','Cabin','Embarked_S','Embarked_Q']
X_train = train_df[features]
Y_train = train_df['Survived']
X_test = test_df[features]


#标准化数据
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

#totensor
X_train_tensor = torch.tensor(X_train,dtype=torch.float32)
Y_train_tensor = torch.tensor(Y_train.values,dtype=torch.float32)
X_test_tensor = torch.tensor(X_test,dtype=torch.float32)



#loaddata
train_dataset = TensorDataset(X_train_tensor,Y_train_tensor)
train_loader = DataLoader(train_dataset, batch_size=64,shuffle=True)



#model
class Net(torch.nn.Module):
    def __init__(self):
        super(Net,self).__init__()
        self.fc1 = torch.nn.Linear(len(features),8)
        self.fc2 = torch.nn.Linear(8,6)
        self.fc3 = torch.nn.Linear(6,3)
        self.fc4 = torch.nn.Linear(3,1)
        self.sigmoid = torch.nn.Sigmoid()

    def forward(self,x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = self.sigmoid(self.fc4(x))
        return x
model = Net()

criterion = torch.nn.BCELoss(reduction = 'mean')
optimizer =  optim.Adam(model.parameters(),lr=0.001)

def train(epoch):
    for batch_idx, data in enumerate (train_loader,0):
        inputs,target = data
        target = target.view(-1,1)

        outputs = model(inputs)
        loss = criterion(outputs,target)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()


def test():
    model.eval()
    predictions=[]
    with torch.no_grad():
        for inputs in X_test_tensor:
            outputs = model(inputs).squeeze()
            predicted = torch.round(outputs).item()
            predictions.append(predicted)
    survived_count = sum(predictions)
    total_count = len(predictions)
    survival_rate = survived_count / total_count * 100
    print(f'Survival Rate: {survival_rate:.2f}%')
    for passenger_id, prediction in zip(test_df['PassengerId'], predictions):
        print('PassengerId: %d, Predicted: %d'% (passenger_id, int(prediction)))

for epoch in range(10):
    train(epoch)
test()
# Out:
# Survival Rate: 22.25%
# PassengerId: 892, Predicted: 0
# PassengerId: 893, Predicted: 0
# PassengerId: 894, Predicted: 0
# PassengerId: 895, Predicted: 0
# PassengerId: 896, Predicted: 0
# PassengerId: 897, Predicted: 0
# PassengerId: 898, Predicted: 1
# PassengerId: 899, Predicted: 0
# PassengerId: 900, Predicted: 1
# PassengerId: 901, Predicted: 0
# PassengerId: 902, Predicted: 0
# PassengerId: 903, Predicted: 0
# PassengerId: 904, Predicted: 1
# PassengerId: 905, Predicted: 0
# PassengerId: 906, Predicted: 0
# PassengerId: 907, Predicted: 1
# PassengerId: 908, Predicted: 0
# PassengerId: 909, Predicted: 0
# PassengerId: 910, Predicted: 0
# PassengerId: 911, Predicted: 0
# PassengerId: 912, Predicted: 0
# PassengerId: 913, Predicted: 0
# PassengerId: 914, Predicted: 1
# PassengerId: 915, Predicted: 0
# PassengerId: 916, Predicted: 1
# PassengerId: 917, Predicted: 0
# PassengerId: 918, Predicted: 1
# PassengerId: 919, Predicted: 0
# PassengerId: 920, Predicted: 0
# PassengerId: 921, Predicted: 0
# PassengerId: 922, Predicted: 0
# PassengerId: 923, Predicted: 0
# PassengerId: 924, Predicted: 0
# PassengerId: 925, Predicted: 0
# PassengerId: 926, Predicted: 0
# PassengerId: 927, Predicted: 0
# PassengerId: 928, Predicted: 0
# PassengerId: 929, Predicted: 0
# PassengerId: 930, Predicted: 0
# PassengerId: 931, Predicted: 0
# PassengerId: 932, Predicted: 0
# PassengerId: 933, Predicted: 0
# PassengerId: 934, Predicted: 0
# PassengerId: 935, Predicted: 0
# PassengerId: 936, Predicted: 1
# PassengerId: 937, Predicted: 0
# PassengerId: 938, Predicted: 0
# PassengerId: 939, Predicted: 0
# PassengerId: 940, Predicted: 1
# PassengerId: 941, Predicted: 0
# PassengerId: 942, Predicted: 0
# PassengerId: 943, Predicted: 0
# PassengerId: 944, Predicted: 0
# PassengerId: 945, Predicted: 1
# PassengerId: 946, Predicted: 0
# PassengerId: 947, Predicted: 0
# PassengerId: 948, Predicted: 0
# PassengerId: 949, Predicted: 0
# PassengerId: 950, Predicted: 0
# PassengerId: 951, Predicted: 1
# PassengerId: 952, Predicted: 0
# PassengerId: 953, Predicted: 0
# PassengerId: 954, Predicted: 0
# PassengerId: 955, Predicted: 1
# PassengerId: 956, Predicted: 1
# PassengerId: 957, Predicted: 1
# PassengerId: 958, Predicted: 1
# PassengerId: 959, Predicted: 0
# PassengerId: 960, Predicted: 0
# PassengerId: 961, Predicted: 1
# PassengerId: 962, Predicted: 1
# PassengerId: 963, Predicted: 0
# PassengerId: 964, Predicted: 0
# PassengerId: 965, Predicted: 0
# PassengerId: 966, Predicted: 1
# PassengerId: 967, Predicted: 1
# PassengerId: 968, Predicted: 0
# PassengerId: 969, Predicted: 1
# PassengerId: 970, Predicted: 0
# PassengerId: 971, Predicted: 1
# PassengerId: 972, Predicted: 0
# PassengerId: 973, Predicted: 0
# PassengerId: 974, Predicted: 0
# PassengerId: 975, Predicted: 0
# PassengerId: 976, Predicted: 0
# PassengerId: 977, Predicted: 0
# PassengerId: 978, Predicted: 1
# PassengerId: 979, Predicted: 0
# PassengerId: 980, Predicted: 1
# PassengerId: 981, Predicted: 0
# PassengerId: 982, Predicted: 0
# PassengerId: 983, Predicted: 0
# PassengerId: 984, Predicted: 1
# PassengerId: 985, Predicted: 0
# PassengerId: 986, Predicted: 0
# PassengerId: 987, Predicted: 0
# PassengerId: 988, Predicted: 0
# PassengerId: 989, Predicted: 0
# PassengerId: 990, Predicted: 0
# PassengerId: 991, Predicted: 0
# PassengerId: 992, Predicted: 1
# PassengerId: 993, Predicted: 0
# PassengerId: 994, Predicted: 0
# PassengerId: 995, Predicted: 0
# PassengerId: 996, Predicted: 1
# PassengerId: 997, Predicted: 0
# PassengerId: 998, Predicted: 0
# PassengerId: 999, Predicted: 0
# PassengerId: 1000, Predicted: 0
# PassengerId: 1001, Predicted: 0
# PassengerId: 1002, Predicted: 0
# PassengerId: 1003, Predicted: 1
# PassengerId: 1004, Predicted: 1
# PassengerId: 1005, Predicted: 1
# PassengerId: 1006, Predicted: 1
# PassengerId: 1007, Predicted: 0
# PassengerId: 1008, Predicted: 0
# PassengerId: 1009, Predicted: 0
# PassengerId: 1010, Predicted: 0
# PassengerId: 1011, Predicted: 0
# PassengerId: 1012, Predicted: 1
# PassengerId: 1013, Predicted: 0
# PassengerId: 1014, Predicted: 1
# PassengerId: 1015, Predicted: 0
# PassengerId: 1016, Predicted: 0
# PassengerId: 1017, Predicted: 0
# PassengerId: 1018, Predicted: 0
# PassengerId: 1019, Predicted: 1
# PassengerId: 1020, Predicted: 0
# PassengerId: 1021, Predicted: 0
# PassengerId: 1022, Predicted: 0
# PassengerId: 1023, Predicted: 0
# PassengerId: 1024, Predicted: 0
# PassengerId: 1025, Predicted: 0
# PassengerId: 1026, Predicted: 0
# PassengerId: 1027, Predicted: 0
# PassengerId: 1028, Predicted: 0
# PassengerId: 1029, Predicted: 0
# PassengerId: 1030, Predicted: 0
# PassengerId: 1031, Predicted: 0
# PassengerId: 1032, Predicted: 0
# PassengerId: 1033, Predicted: 1
# PassengerId: 1034, Predicted: 0
# PassengerId: 1035, Predicted: 0
# PassengerId: 1036, Predicted: 0
# PassengerId: 1037, Predicted: 0
# PassengerId: 1038, Predicted: 0
# PassengerId: 1039, Predicted: 0
# PassengerId: 1040, Predicted: 0
# PassengerId: 1041, Predicted: 0
# PassengerId: 1042, Predicted: 1
# PassengerId: 1043, Predicted: 0
# PassengerId: 1044, Predicted: 0
# PassengerId: 1045, Predicted: 0
# PassengerId: 1046, Predicted: 0
# PassengerId: 1047, Predicted: 0
# PassengerId: 1048, Predicted: 1
# PassengerId: 1049, Predicted: 0
# PassengerId: 1050, Predicted: 0
# PassengerId: 1051, Predicted: 0
# PassengerId: 1052, Predicted: 1
# PassengerId: 1053, Predicted: 0
# PassengerId: 1054, Predicted: 1
# PassengerId: 1055, Predicted: 0
# PassengerId: 1056, Predicted: 0
# PassengerId: 1057, Predicted: 0
# PassengerId: 1058, Predicted: 0
# PassengerId: 1059, Predicted: 0
# PassengerId: 1060, Predicted: 1
# PassengerId: 1061, Predicted: 0
# PassengerId: 1062, Predicted: 0
# PassengerId: 1063, Predicted: 0
# PassengerId: 1064, Predicted: 0
# PassengerId: 1065, Predicted: 0
# PassengerId: 1066, Predicted: 0
# PassengerId: 1067, Predicted: 1
# PassengerId: 1068, Predicted: 1
# PassengerId: 1069, Predicted: 0
# PassengerId: 1070, Predicted: 0
# PassengerId: 1071, Predicted: 0
# PassengerId: 1072, Predicted: 0
# PassengerId: 1073, Predicted: 0
# PassengerId: 1074, Predicted: 1
# PassengerId: 1075, Predicted: 0
# PassengerId: 1076, Predicted: 1
# PassengerId: 1077, Predicted: 0
# PassengerId: 1078, Predicted: 1
# PassengerId: 1079, Predicted: 0
# PassengerId: 1080, Predicted: 0
# PassengerId: 1081, Predicted: 0
# PassengerId: 1082, Predicted: 0
# PassengerId: 1083, Predicted: 0
# PassengerId: 1084, Predicted: 0
# PassengerId: 1085, Predicted: 0
# PassengerId: 1086, Predicted: 0
# PassengerId: 1087, Predicted: 0
# PassengerId: 1088, Predicted: 1
# PassengerId: 1089, Predicted: 0
# PassengerId: 1090, Predicted: 0
# PassengerId: 1091, Predicted: 0
# PassengerId: 1092, Predicted: 1
# PassengerId: 1093, Predicted: 0
# PassengerId: 1094, Predicted: 1
# PassengerId: 1095, Predicted: 1
# PassengerId: 1096, Predicted: 0
# PassengerId: 1097, Predicted: 0
# PassengerId: 1098, Predicted: 0
# PassengerId: 1099, Predicted: 0
# PassengerId: 1100, Predicted: 1
# PassengerId: 1101, Predicted: 0
# PassengerId: 1102, Predicted: 0
# PassengerId: 1103, Predicted: 0
# PassengerId: 1104, Predicted: 0
# PassengerId: 1105, Predicted: 0
# PassengerId: 1106, Predicted: 0
# PassengerId: 1107, Predicted: 0
# PassengerId: 1108, Predicted: 1
# PassengerId: 1109, Predicted: 0
# PassengerId: 1110, Predicted: 1
# PassengerId: 1111, Predicted: 0
# PassengerId: 1112, Predicted: 1
# PassengerId: 1113, Predicted: 0
# PassengerId: 1114, Predicted: 1
# PassengerId: 1115, Predicted: 0
# PassengerId: 1116, Predicted: 0
# PassengerId: 1117, Predicted: 0
# PassengerId: 1118, Predicted: 0
# PassengerId: 1119, Predicted: 1
# PassengerId: 1120, Predicted: 0
# PassengerId: 1121, Predicted: 0
# PassengerId: 1122, Predicted: 0
# PassengerId: 1123, Predicted: 1
# PassengerId: 1124, Predicted: 0
# PassengerId: 1125, Predicted: 0
# PassengerId: 1126, Predicted: 0
# PassengerId: 1127, Predicted: 0
# PassengerId: 1128, Predicted: 0
# PassengerId: 1129, Predicted: 0
# PassengerId: 1130, Predicted: 0
# PassengerId: 1131, Predicted: 1
# PassengerId: 1132, Predicted: 0
# PassengerId: 1133, Predicted: 0
# PassengerId: 1134, Predicted: 0
# PassengerId: 1135, Predicted: 0
# PassengerId: 1136, Predicted: 0
# PassengerId: 1137, Predicted: 0
# PassengerId: 1138, Predicted: 1
# PassengerId: 1139, Predicted: 0
# PassengerId: 1140, Predicted: 1
# PassengerId: 1141, Predicted: 1
# PassengerId: 1142, Predicted: 1
# PassengerId: 1143, Predicted: 0
# PassengerId: 1144, Predicted: 1
# PassengerId: 1145, Predicted: 0
# PassengerId: 1146, Predicted: 0
# PassengerId: 1147, Predicted: 0
# PassengerId: 1148, Predicted: 0
# PassengerId: 1149, Predicted: 0
# PassengerId: 1150, Predicted: 1
# PassengerId: 1151, Predicted: 0
# PassengerId: 1152, Predicted: 0
# PassengerId: 1153, Predicted: 0
# PassengerId: 1154, Predicted: 0
# PassengerId: 1155, Predicted: 0
# PassengerId: 1156, Predicted: 0
# PassengerId: 1157, Predicted: 0
# PassengerId: 1158, Predicted: 0
# PassengerId: 1159, Predicted: 0
# PassengerId: 1160, Predicted: 0
# PassengerId: 1161, Predicted: 0
# PassengerId: 1162, Predicted: 0
# PassengerId: 1163, Predicted: 0
# PassengerId: 1164, Predicted: 1
# PassengerId: 1165, Predicted: 1
# PassengerId: 1166, Predicted: 0
# PassengerId: 1167, Predicted: 0
# PassengerId: 1168, Predicted: 0
# PassengerId: 1169, Predicted: 0
# PassengerId: 1170, Predicted: 0
# PassengerId: 1171, Predicted: 0
# PassengerId: 1172, Predicted: 0
# PassengerId: 1173, Predicted: 0
# PassengerId: 1174, Predicted: 1
# PassengerId: 1175, Predicted: 1
# PassengerId: 1176, Predicted: 0
# PassengerId: 1177, Predicted: 0
# PassengerId: 1178, Predicted: 0
# PassengerId: 1179, Predicted: 0
# PassengerId: 1180, Predicted: 0
# PassengerId: 1181, Predicted: 0
# PassengerId: 1182, Predicted: 0
# PassengerId: 1183, Predicted: 1
# PassengerId: 1184, Predicted: 0
# PassengerId: 1185, Predicted: 0
# PassengerId: 1186, Predicted: 0
# PassengerId: 1187, Predicted: 0
# PassengerId: 1188, Predicted: 1
# PassengerId: 1189, Predicted: 0
# PassengerId: 1190, Predicted: 0
# PassengerId: 1191, Predicted: 0
# PassengerId: 1192, Predicted: 0
# PassengerId: 1193, Predicted: 0
# PassengerId: 1194, Predicted: 0
# PassengerId: 1195, Predicted: 0
# PassengerId: 1196, Predicted: 1
# PassengerId: 1197, Predicted: 0
# PassengerId: 1198, Predicted: 0
# PassengerId: 1199, Predicted: 0
# PassengerId: 1200, Predicted: 0
# PassengerId: 1201, Predicted: 0
# PassengerId: 1202, Predicted: 0
# PassengerId: 1203, Predicted: 0
# PassengerId: 1204, Predicted: 0
# PassengerId: 1205, Predicted: 0
# PassengerId: 1206, Predicted: 1
# PassengerId: 1207, Predicted: 1
# PassengerId: 1208, Predicted: 0
# PassengerId: 1209, Predicted: 0
# PassengerId: 1210, Predicted: 0
# PassengerId: 1211, Predicted: 0
# PassengerId: 1212, Predicted: 0
# PassengerId: 1213, Predicted: 0
# PassengerId: 1214, Predicted: 0
# PassengerId: 1215, Predicted: 0
# PassengerId: 1216, Predicted: 1
# PassengerId: 1217, Predicted: 0
# PassengerId: 1218, Predicted: 1
# PassengerId: 1219, Predicted: 0
# PassengerId: 1220, Predicted: 0
# PassengerId: 1221, Predicted: 0
# PassengerId: 1222, Predicted: 0
# PassengerId: 1223, Predicted: 0
# PassengerId: 1224, Predicted: 0
# PassengerId: 1225, Predicted: 1
# PassengerId: 1226, Predicted: 0
# PassengerId: 1227, Predicted: 0
# PassengerId: 1228, Predicted: 0
# PassengerId: 1229, Predicted: 0
# PassengerId: 1230, Predicted: 0
# PassengerId: 1231, Predicted: 0
# PassengerId: 1232, Predicted: 0
# PassengerId: 1233, Predicted: 0
# PassengerId: 1234, Predicted: 0
# PassengerId: 1235, Predicted: 1
# PassengerId: 1236, Predicted: 0
# PassengerId: 1237, Predicted: 0
# PassengerId: 1238, Predicted: 0
# PassengerId: 1239, Predicted: 0
# PassengerId: 1240, Predicted: 0
# PassengerId: 1241, Predicted: 1
# PassengerId: 1242, Predicted: 1
# PassengerId: 1243, Predicted: 0
# PassengerId: 1244, Predicted: 0
# PassengerId: 1245, Predicted: 0
# PassengerId: 1246, Predicted: 0
# PassengerId: 1247, Predicted: 0
# PassengerId: 1248, Predicted: 1
# PassengerId: 1249, Predicted: 0
# PassengerId: 1250, Predicted: 0
# PassengerId: 1251, Predicted: 0
# PassengerId: 1252, Predicted: 0
# PassengerId: 1253, Predicted: 1
# PassengerId: 1254, Predicted: 0
# PassengerId: 1255, Predicted: 0
# PassengerId: 1256, Predicted: 1
# PassengerId: 1257, Predicted: 0
# PassengerId: 1258, Predicted: 0
# PassengerId: 1259, Predicted: 0
# PassengerId: 1260, Predicted: 1
# PassengerId: 1261, Predicted: 0
# PassengerId: 1262, Predicted: 0
# PassengerId: 1263, Predicted: 1
# PassengerId: 1264, Predicted: 0
# PassengerId: 1265, Predicted: 0
# PassengerId: 1266, Predicted: 0
# PassengerId: 1267, Predicted: 1
# PassengerId: 1268, Predicted: 0
# PassengerId: 1269, Predicted: 0
# PassengerId: 1270, Predicted: 0
# PassengerId: 1271, Predicted: 0
# PassengerId: 1272, Predicted: 0
# PassengerId: 1273, Predicted: 0
# PassengerId: 1274, Predicted: 0
# PassengerId: 1275, Predicted: 0
# PassengerId: 1276, Predicted: 0
# PassengerId: 1277, Predicted: 0
# PassengerId: 1278, Predicted: 0
# PassengerId: 1279, Predicted: 0
# PassengerId: 1280, Predicted: 0
# PassengerId: 1281, Predicted: 0
# PassengerId: 1282, Predicted: 1
# PassengerId: 1283, Predicted: 1
# PassengerId: 1284, Predicted: 0
# PassengerId: 1285, Predicted: 0
# PassengerId: 1286, Predicted: 0
# PassengerId: 1287, Predicted: 1
# PassengerId: 1288, Predicted: 0
# PassengerId: 1289, Predicted: 1
# PassengerId: 1290, Predicted: 0
# PassengerId: 1291, Predicted: 0
# PassengerId: 1292, Predicted: 1
# PassengerId: 1293, Predicted: 0
# PassengerId: 1294, Predicted: 1
# PassengerId: 1295, Predicted: 0
# PassengerId: 1296, Predicted: 0
# PassengerId: 1297, Predicted: 0
# PassengerId: 1298, Predicted: 0
# PassengerId: 1299, Predicted: 0
# PassengerId: 1300, Predicted: 1
# PassengerId: 1301, Predicted: 0
# PassengerId: 1302, Predicted: 1
# PassengerId: 1303, Predicted: 1
# PassengerId: 1304, Predicted: 0
# PassengerId: 1305, Predicted: 0
# PassengerId: 1306, Predicted: 1
# PassengerId: 1307, Predicted: 0
# PassengerId: 1308, Predicted: 0
# PassengerId: 1309, Predicted: 0
# /private/tmp/PKInstallSandbox.evc6YQ/tmp/ipykernel_82432/4234588089.py:18: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_df['Age'].fillna(train_df['Age'].mean(),inplace = True)
# /private/tmp/PKInstallSandbox.evc6YQ/tmp/ipykernel_82432/4234588089.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_df['Embarked'].fillna(train_df['Embarked'].mode()[0],inplace = True)
# /private/tmp/PKInstallSandbox.evc6YQ/tmp/ipykernel_82432/4234588089.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_df['Fare'].fillna(train_df['Fare'].median(),inplace= True)
# /private/tmp/PKInstallSandbox.evc6YQ/tmp/ipykernel_82432/4234588089.py:22: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_df['Cabin'].fillna('Unknown',inplace=True)
# /private/tmp/PKInstallSandbox.evc6YQ/tmp/ipykernel_82432/4234588089.py:23: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_df['Name'].fillna('Unknown',inplace=True)
# /private/tmp/PKInstallSandbox.evc6YQ/tmp/ipykernel_82432/4234588089.py:24: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_df['Ticket'].fillna('Unknown',inplace=True)
# /private/tmp/PKInstallSandbox.evc6YQ/tmp/ipykernel_82432/4234588089.py:26: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test_df['Age'].fillna(test_df['Age'].mean(),inplace=True)
# /private/tmp/PKInstallSandbox.evc6YQ/tmp/ipykernel_82432/4234588089.py:27: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test_df['Embarked'].fillna(test_df['Embarked'].mode()[0],inplace= True)
# /private/tmp/PKInstallSandbox.evc6YQ/tmp/ipykernel_82432/4234588089.py:28: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test_df['Fare'].fillna(test_df['Fare'].median(),inplace=True)
# /private/tmp/PKInstallSandbox.evc6YQ/tmp/ipykernel_82432/4234588089.py:29: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test_df['Cabin'].fillna('Unknown',inplace=True)
# /private/tmp/PKInstallSandbox.evc6YQ/tmp/ipykernel_82432/4234588089.py:30: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test_df['Name'].fillna('Unknown',inplace=True)
# /private/tmp/PKInstallSandbox.evc6YQ/tmp/ipykernel_82432/4234588089.py:31: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test_df['Ticket'].fillna('Unknown',inplace=True)
